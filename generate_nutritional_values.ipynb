# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, max, count, collect_list, concat_ws, coalesce, upper
import os

# Configure Spark for Windows compatibility
spark = SparkSession.builder \
    .appName("NutritionalValuesGenerator") \
    .config("spark.sql.shuffle.partitions", "50") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version", "2") \
    .config("spark.speculation", "false") \
    .config("spark.hadoop.mapreduce.fileoutputcommitter.cleanup-failures.ignored", "true") \
    .getOrCreate()

spark.sparkContext.setLogLevel("WARN")

# %%
dataset_dir = "D:/1-master/2024-2026/1-ISST/BigDataAnalitics/1-labs/fii-bda/FII-BDA/sampled_dataset"


df_food = spark.read.parquet(f"{dataset_dir}/food.parquet")
df_food_nutrient = spark.read.parquet(f"{dataset_dir}/food_nutrient.parquet")
df_nutrient = spark.read.parquet(f"{dataset_dir}/nutrient.parquet")
df_food_portion = spark.read.parquet(f"{dataset_dir}/food_portion.parquet")
df_measure_unit = spark.read.parquet(f"{dataset_dir}/measure_unit.parquet")


print(f"Food records: {df_food.count()}")
print(f"Food-Nutrient records: {df_food_nutrient.count()}")
print(f"Nutrient records: {df_nutrient.count()}")
print(f"Food Portion records: {df_food_portion.count()}")
print(f"Measure Unit records: {df_measure_unit.count()}")
# Out:
# Food records: 5000
# Food-Nutrient records: 65141
# Nutrient records: 477
# Food Portion records: 104
# Measure Unit records: 5

# %%
df_food_nutrient_clean = df_food_nutrient.select(
    col("fdc_id"),
    col("nutrient_id"),
    col("amount"),
    col("data_points"),
    col("min"),
    col("max"),
    col("median")
).filter(col("amount").isNotNull())

df_nutrient_clean = df_nutrient.select(
    col("id").alias("nutrient_id"),
    col("name").alias("nutrient_name"),
    col("unit_name").alias("nutrient_unit"),
    col("rank")
)

df_food_enriched = df_food.select(
    col("fdc_id"),
    col("description"),
    col("data_type")
)

df_merged = df_food_enriched.join(
    df_food_nutrient_clean,
    on="fdc_id",
    how="inner"
).join(
    df_nutrient_clean,
    on="nutrient_id",
    how="left"
)

df_merged = df_merged.fillna("Unknown", subset=["nutrient_name", "nutrient_unit"])

df_merged = df_merged.withColumn(
    "nutrient_display",
    when(col("nutrient_unit").isNotNull(),
         concat_ws(" (", col("nutrient_name"), concat_ws(")", col("nutrient_unit")))
    ).otherwise(col("nutrient_name"))
)

print(f"Merged records: {df_merged.count()}")
# Out:
# Merged records: 65141

# %%
df_aggregated = df_merged.groupBy("fdc_id", "description", "data_type").agg(
    collect_list("nutrient_display").alias("nutrients"),
    collect_list("amount").alias("amounts"),
    collect_list("median").alias("medians"),
    collect_list("min").alias("mins"),
    collect_list("max").alias("maxs"),
    count("nutrient_id").alias("total_nutrients")
)

df_aggregated = df_aggregated.withColumn(
    "nutrients_json",
    concat_ws("|", col("nutrients"))
)

df_pivot = df_merged.groupBy("fdc_id").pivot("nutrient_name").agg(
    coalesce(
        max(when(col("nutrient_name").isNotNull(), col("amount"))),
        max(when(col("nutrient_name").isNotNull(), col("median")))
    ).alias("amount")
)

print(f"Aggregated foods: {df_aggregated.count()}")
print(f"Pivot table columns: {len(df_pivot.columns)}")
print(f"Foods with nutrients: {df_pivot.count()}")
# Out:
# Aggregated foods: 4688
# Pivot table columns: 180
# Foods with nutrients: 4688

# %%
df_merged_clean = df_merged.filter(col("amount").isNotNull())

# Macronutrients
energy_col = df_merged_clean.filter(col("nutrient_name") == "Energy").select("fdc_id", col("amount").alias("energy")).dropDuplicates(["fdc_id"])
protein_col = df_merged_clean.filter(upper(col("nutrient_name")).contains("PROTEIN")).select("fdc_id", col("amount").alias("protein")).dropDuplicates(["fdc_id"])
carbs_col = df_merged_clean.filter(col("nutrient_name") == "Carbohydrate, by difference").select("fdc_id", col("amount").alias("carbs")).dropDuplicates(["fdc_id"])
total_fat_col = df_merged_clean.filter(col("nutrient_name") == "Total lipid (fat)").select("fdc_id", col("amount").alias("total_fat")).dropDuplicates(["fdc_id"])

# Food composition basics
water_col = df_merged_clean.filter(col("nutrient_name") == "Water").select("fdc_id", col("amount").alias("water")).dropDuplicates(["fdc_id"])
ash_col = df_merged_clean.filter(col("nutrient_name") == "Ash").select("fdc_id", col("amount").alias("ash")).dropDuplicates(["fdc_id"])
alcohol_col = df_merged_clean.filter(col("nutrient_name") == "Alcohol, ethyl").select("fdc_id", col("amount").alias("alcohol")).dropDuplicates(["fdc_id"])
caffeine_col = df_merged_clean.filter(col("nutrient_name") == "Caffeine").select("fdc_id", col("amount").alias("caffeine")).dropDuplicates(["fdc_id"])

# Fiber and Sugars
fiber_col = df_merged_clean.filter(col("nutrient_name").contains("Fiber, total dietary")).select("fdc_id", col("amount").alias("fiber")).dropDuplicates(["fdc_id"])
sugars_col = df_merged_clean.filter(col("nutrient_name") == "Total Sugars").select("fdc_id", col("amount").alias("sugars")).dropDuplicates(["fdc_id"])

# Sugar types
glucose_col = df_merged_clean.filter(col("nutrient_name") == "Glucose").select("fdc_id", col("amount").alias("glucose")).dropDuplicates(["fdc_id"])
fructose_col = df_merged_clean.filter(col("nutrient_name") == "Fructose").select("fdc_id", col("amount").alias("fructose")).dropDuplicates(["fdc_id"])
sucrose_col = df_merged_clean.filter(col("nutrient_name") == "Sucrose").select("fdc_id", col("amount").alias("sucrose")).dropDuplicates(["fdc_id"])
lactose_col = df_merged_clean.filter(col("nutrient_name") == "Lactose").select("fdc_id", col("amount").alias("lactose")).dropDuplicates(["fdc_id"])

# Fats breakdown
saturated_fat_col = df_merged_clean.filter(col("nutrient_name") == "Fatty acids, total saturated").select("fdc_id", col("amount").alias("saturated_fat")).dropDuplicates(["fdc_id"])
monounsaturated_fat_col = df_merged_clean.filter(col("nutrient_name") == "Fatty acids, total monounsaturated").select("fdc_id", col("amount").alias("monounsaturated_fat")).dropDuplicates(["fdc_id"])
polyunsaturated_fat_col = df_merged_clean.filter(col("nutrient_name") == "Fatty acids, total polyunsaturated").select("fdc_id", col("amount").alias("polyunsaturated_fat")).dropDuplicates(["fdc_id"])
trans_fat_col = df_merged_clean.filter(col("nutrient_name") == "Fatty acids, total trans").select("fdc_id", col("amount").alias("trans_fat")).dropDuplicates(["fdc_id"])
cholesterol_col = df_merged_clean.filter(col("nutrient_name") == "Cholesterol").select("fdc_id", col("amount").alias("cholesterol")).dropDuplicates(["fdc_id"])

# Vitamins
vitamin_a_col = df_merged_clean.filter(col("nutrient_name").contains("Vitamin A, RAE")).select("fdc_id", col("amount").alias("vitamin_a")).dropDuplicates(["fdc_id"])
vitamin_c_col = df_merged_clean.filter(col("nutrient_name").contains("Vitamin C")).select("fdc_id", col("amount").alias("vitamin_c")).dropDuplicates(["fdc_id"])
vitamin_d_col = df_merged_clean.filter(col("nutrient_name").contains("Vitamin D (D2 + D3)")).select("fdc_id", col("amount").alias("vitamin_d")).dropDuplicates(["fdc_id"])
vitamin_e_col = df_merged_clean.filter(col("nutrient_name").contains("Vitamin E (alpha-tocopherol)")).select("fdc_id", col("amount").alias("vitamin_e")).dropDuplicates(["fdc_id"])
vitamin_k_col = df_merged_clean.filter(col("nutrient_name").contains("Vitamin K (phylloquinone)")).select("fdc_id", col("amount").alias("vitamin_k")).dropDuplicates(["fdc_id"])

# B Vitamins
thiamin_col = df_merged_clean.filter(col("nutrient_name").contains("Thiamin")).select("fdc_id", col("amount").alias("thiamin_b1")).dropDuplicates(["fdc_id"])
riboflavin_col = df_merged_clean.filter(col("nutrient_name").contains("Riboflavin")).select("fdc_id", col("amount").alias("riboflavin_b2")).dropDuplicates(["fdc_id"])
niacin_col = df_merged_clean.filter(col("nutrient_name").contains("Niacin")).select("fdc_id", col("amount").alias("niacin_b3")).dropDuplicates(["fdc_id"])
vitamin_b6_col = df_merged_clean.filter(col("nutrient_name").contains("Vitamin B-6")).select("fdc_id", col("amount").alias("vitamin_b6")).dropDuplicates(["fdc_id"])
folate_col = df_merged_clean.filter(col("nutrient_name") == "Folate, total").select("fdc_id", col("amount").alias("folate")).dropDuplicates(["fdc_id"])
vitamin_b12_col = df_merged_clean.filter(col("nutrient_name").contains("Vitamin B-12")).select("fdc_id", col("amount").alias("vitamin_b12")).dropDuplicates(["fdc_id"])

# Additional micronutrients
choline_col = df_merged_clean.filter(col("nutrient_name").contains("Choline, total")).select("fdc_id", col("amount").alias("choline")).dropDuplicates(["fdc_id"])

# Minerals
calcium_col = df_merged_clean.filter(col("nutrient_name") == "Calcium, Ca").select("fdc_id", col("amount").alias("calcium")).dropDuplicates(["fdc_id"])
iron_col = df_merged_clean.filter(col("nutrient_name") == "Iron, Fe").select("fdc_id", col("amount").alias("iron")).dropDuplicates(["fdc_id"])
magnesium_col = df_merged_clean.filter(col("nutrient_name") == "Magnesium, Mg").select("fdc_id", col("amount").alias("magnesium")).dropDuplicates(["fdc_id"])
phosphorus_col = df_merged_clean.filter(col("nutrient_name") == "Phosphorus, P").select("fdc_id", col("amount").alias("phosphorus")).dropDuplicates(["fdc_id"])
potassium_col = df_merged_clean.filter(col("nutrient_name") == "Potassium, K").select("fdc_id", col("amount").alias("potassium")).dropDuplicates(["fdc_id"])
sodium_col = df_merged_clean.filter(col("nutrient_name") == "Sodium, Na").select("fdc_id", col("amount").alias("sodium")).dropDuplicates(["fdc_id"])
zinc_col = df_merged_clean.filter(col("nutrient_name") == "Zinc, Zn").select("fdc_id", col("amount").alias("zinc")).dropDuplicates(["fdc_id"])
copper_col = df_merged_clean.filter(col("nutrient_name") == "Copper, Cu").select("fdc_id", col("amount").alias("copper")).dropDuplicates(["fdc_id"])
manganese_col = df_merged_clean.filter(col("nutrient_name") == "Manganese, Mn").select("fdc_id", col("amount").alias("manganese")).dropDuplicates(["fdc_id"])
selenium_col = df_merged_clean.filter(col("nutrient_name") == "Selenium, Se").select("fdc_id", col("amount").alias("selenium")).dropDuplicates(["fdc_id"])

# Carotenoids and antioxidants
beta_carotene_col = df_merged_clean.filter(col("nutrient_name").contains("Carotene, beta")).select("fdc_id", col("amount").alias("beta_carotene")).dropDuplicates(["fdc_id"])
lycopene_col = df_merged_clean.filter(col("nutrient_name") == "Lycopene").select("fdc_id", col("amount").alias("lycopene")).dropDuplicates(["fdc_id"])
lutein_col = df_merged_clean.filter(col("nutrient_name").contains("Lutein + zeaxanthin")).select("fdc_id", col("amount").alias("lutein_zeaxanthin")).dropDuplicates(["fdc_id"])

# Join all nutrients
df_metrics = df_food_enriched.join(energy_col, on="fdc_id", how="left") \
    .join(protein_col, on="fdc_id", how="left") \
    .join(carbs_col, on="fdc_id", how="left") \
    .join(total_fat_col, on="fdc_id", how="left") \
    .join(water_col, on="fdc_id", how="left") \
    .join(ash_col, on="fdc_id", how="left") \
    .join(alcohol_col, on="fdc_id", how="left") \
    .join(caffeine_col, on="fdc_id", how="left") \
    .join(fiber_col, on="fdc_id", how="left") \
    .join(sugars_col, on="fdc_id", how="left") \
    .join(glucose_col, on="fdc_id", how="left") \
    .join(fructose_col, on="fdc_id", how="left") \
    .join(sucrose_col, on="fdc_id", how="left") \
    .join(lactose_col, on="fdc_id", how="left") \
    .join(saturated_fat_col, on="fdc_id", how="left") \
    .join(monounsaturated_fat_col, on="fdc_id", how="left") \
    .join(polyunsaturated_fat_col, on="fdc_id", how="left") \
    .join(trans_fat_col, on="fdc_id", how="left") \
    .join(cholesterol_col, on="fdc_id", how="left") \
    .join(vitamin_a_col, on="fdc_id", how="left") \
    .join(vitamin_c_col, on="fdc_id", how="left") \
    .join(vitamin_d_col, on="fdc_id", how="left") \
    .join(vitamin_e_col, on="fdc_id", how="left") \
    .join(vitamin_k_col, on="fdc_id", how="left") \
    .join(thiamin_col, on="fdc_id", how="left") \
    .join(riboflavin_col, on="fdc_id", how="left") \
    .join(niacin_col, on="fdc_id", how="left") \
    .join(vitamin_b6_col, on="fdc_id", how="left") \
    .join(folate_col, on="fdc_id", how="left") \
    .join(vitamin_b12_col, on="fdc_id", how="left") \
    .join(choline_col, on="fdc_id", how="left") \
    .join(calcium_col, on="fdc_id", how="left") \
    .join(iron_col, on="fdc_id", how="left") \
    .join(magnesium_col, on="fdc_id", how="left") \
    .join(phosphorus_col, on="fdc_id", how="left") \
    .join(potassium_col, on="fdc_id", how="left") \
    .join(sodium_col, on="fdc_id", how="left") \
    .join(zinc_col, on="fdc_id", how="left") \
    .join(copper_col, on="fdc_id", how="left") \
    .join(manganese_col, on="fdc_id", how="left") \
    .join(selenium_col, on="fdc_id", how="left") \
    .join(beta_carotene_col, on="fdc_id", how="left") \
    .join(lycopene_col, on="fdc_id", how="left") \
    .join(lutein_col, on="fdc_id", how="left")

print(f"Foods with energy: {df_metrics.filter(col('energy').isNotNull()).count()}")
print(f"Foods with protein: {df_metrics.filter(col('protein').isNotNull()).count()}")
print(f"Foods with carbs: {df_metrics.filter(col('carbs').isNotNull()).count()}")
print(f"Foods with total fat: {df_metrics.filter(col('total_fat').isNotNull()).count()}")
print(f"Foods with water: {df_metrics.filter(col('water').isNotNull()).count()}")
print(f"Foods with fiber: {df_metrics.filter(col('fiber').isNotNull()).count()}")
print(f"Foods with vitamin C: {df_metrics.filter(col('vitamin_c').isNotNull()).count()}")
print(f"Foods with calcium: {df_metrics.filter(col('calcium').isNotNull()).count()}")
print(f"Foods with iron: {df_metrics.filter(col('iron').isNotNull()).count()}")
# Out:
# Foods with energy: 4485
# Foods with protein: 4550
# Foods with carbs: 4513
# Foods with total fat: 4505
# Foods with water: 50
# Foods with fiber: 3827
# Foods with vitamin C: 2136
# Foods with calcium: 3741
# Foods with iron: 3747

# %%
df_final_profile = df_aggregated.select(
    col("fdc_id"),
    col("description").alias("food_description"),
    col("data_type").alias("food_type"),
    col("total_nutrients")
).join(
    df_metrics.select(
        "fdc_id", "energy", "protein", "carbs", "total_fat", 
        "water", "ash", "alcohol", "caffeine",
        "fiber", "sugars", "glucose", "fructose", "sucrose", "lactose",
        "saturated_fat", "monounsaturated_fat", "polyunsaturated_fat", "trans_fat", "cholesterol",
        "vitamin_a", "vitamin_c", "vitamin_d", "vitamin_e", "vitamin_k",
        "thiamin_b1", "riboflavin_b2", "niacin_b3", "vitamin_b6", "folate", "vitamin_b12",
        "choline",
        "calcium", "iron", "magnesium", "phosphorus", "potassium", "sodium", 
        "zinc", "copper", "manganese", "selenium",
        "beta_carotene", "lycopene", "lutein_zeaxanthin"
    ),
    on="fdc_id",
    how="left"
)

df_final_profile = df_final_profile.select(
    "fdc_id",
    "food_description",
    "food_type",
    "total_nutrients",
    # Macronutrients
    "energy",
    "protein",
    "carbs",
    "total_fat",
    # Food composition
    "water",
    "ash",
    "alcohol",
    "caffeine",
    # Fiber and Sugars
    "fiber",
    "sugars",
    "glucose",
    "fructose",
    "sucrose",
    "lactose",
    # Fats breakdown
    "saturated_fat",
    "monounsaturated_fat",
    "polyunsaturated_fat",
    "trans_fat",
    "cholesterol",
    # Vitamins
    "vitamin_a",
    "vitamin_c",
    "vitamin_d",
    "vitamin_e",
    "vitamin_k",
    # B Vitamins
    "thiamin_b1",
    "riboflavin_b2",
    "niacin_b3",
    "vitamin_b6",
    "folate",
    "vitamin_b12",
    # Additional nutrients
    "choline",
    # Minerals
    "calcium",
    "iron",
    "magnesium",
    "phosphorus",
    "potassium",
    "sodium",
    "zinc",
    "copper",
    "manganese",
    "selenium",
    # Carotenoids
    "beta_carotene",
    "lycopene",
    "lutein_zeaxanthin"
)

print(f"Final nutritional profiles: {df_final_profile.count()}")
print(f"Total columns: {len(df_final_profile.columns)}")
print(f"\nSample of comprehensive nutritional data:")
df_final_profile.show(5, truncate=False)
# Out:
# Final nutritional profiles: 4688
# Total columns: 48
#
# Sample of comprehensive nutritional data:
# +------+-------------------------------------+------------+---------------+------+-------+-----+---------+-----+----+-------+--------+-----+------+-------+--------+-------+-------+-------------+-------------------+-------------------+---------+-----------+---------+---------+---------+---------+---------+----------+-------------+---------+----------+------+-----------+-------+-------+----+---------+----------+---------+------+----+------+---------+--------+-------------+--------+-----------------+
# ...

# %%
import os
from pathlib import Path

# Use Windows-compatible path (same directory level as sampled_dataset)
output_dir = "D:/1-master/2024-2026/1-ISST/BigDataAnalitics/1-labs/fii-bda/FII-BDA/output"
output_path = f"{output_dir}/nutritional_profiles"
os.makedirs(output_dir, exist_ok=True)

# Set Hadoop system properties for Windows compatibility (works without restarting kernel)
spark.sparkContext._jsc.hadoopConfiguration().set(
    "mapreduce.fileoutputcommitter.algorithm.version", "2"
)
spark.sparkContext._jsc.hadoopConfiguration().set(
    "mapreduce.fileoutputcommitter.cleanup-failures.ignored", "true"
)

# Try Spark write first, fallback to pandas/pyarrow if it fails
try:
    df_final_profile.repartition(1).write.mode("overwrite").parquet(output_path)
    print(f"[OK] Results exported to {output_path} using Spark")
except Exception as e:
    print(f"[WARN] Spark write failed (Windows native IO issue): {str(e)[:200]}...")
    print("Falling back to pandas/pyarrow write...")
    
    # Convert to pandas and write with pyarrow
    import pandas as pd
    
    try:
        # Ensure output directory exists
        Path(output_path).mkdir(parents=True, exist_ok=True)
        
        # Convert Spark DataFrame to pandas
        print("Converting Spark DataFrame to pandas...")
        pdf = df_final_profile.toPandas()
        print(f"Converted {len(pdf)} rows, {len(pdf.columns)} columns")
        
        # Write to parquet file
        output_file = f"{output_path}/nutritional_profiles.parquet"
        print(f"Writing to {output_file}...")
        pdf.to_parquet(
            output_file,
            engine="pyarrow",
            index=False
        )
        
        # Verify file was created
        if os.path.exists(output_file):
            file_size = os.path.getsize(output_file) / (1024 * 1024)  # MB
            print(f"[OK] Results exported successfully!")
            print(f"   File: {output_file}")
            print(f"   Size: {file_size:.2f} MB")
            print(f"   Rows: {len(pdf):,}")
            print(f"   Columns: {len(pdf.columns)}")
        else:
            print(f"❌ Error: File was not created at {output_file}")
            
    except Exception as e2:
        print(f"❌ Pandas/pyarrow write also failed: {e2}")
        import traceback
        traceback.print_exc()

print("\nGenerated files:")
if os.path.exists(output_path):
    files = [f for f in os.listdir(output_path) if os.path.isfile(os.path.join(output_path, f))]
    if files:
        for f in files:
            print(f"  - {f}")
    else:
        print("  (directory exists but no files found)")
else:
    print(f"  (directory {output_path} does not exist)")
# Out:
# [WARN] Spark write failed (Windows native IO issue): An error occurred while calling o1554.parquet.
# : org.apache.spark.SparkException: [TASK_WRITE_FAILED] Task failed while writing rows to file:/D:/1-master/2024-2026/1-ISST/BigDataAnalitics/1-labs/fii-b...
# Falling back to pandas/pyarrow write...
# Converting Spark DataFrame to pandas...
# Converted 4688 rows, 48 columns
# Writing to D:/1-master/2024-2026/1-ISST/BigDataAnalitics/1-labs/fii-bda/FII-BDA/output/nutritional_profiles/nutritional_profiles.parquet...
# [OK] Results exported successfully!
#    File: D:/1-master/2024-2026/1-ISST/BigDataAnalitics/1-labs/fii-bda/FII-BDA/output/nutritional_profiles/nutritional_profiles.parquet
#    Size: 0.30 MB
#    Rows: 4,688
#    Columns: 48
#
# Generated files:
#   - nutritional_profiles.parquet

# %% [markdown]
# ## 7. Food Statistics: Top Nutritious Foods

# %%
from pyspark.sql.functions import (
    col, when, lit, coalesce, desc, round as spark_round, concat_ws
)

# Calculate nutrition density score
# Score = (protein + fiber + vitamins + minerals) / energy
# Higher score = more nutrients per calorie

df_nutrition_score = df_final_profile.withColumn(
    "protein_score",
    when(col("energy").isNotNull() & (col("energy") > 0) & col("protein").isNotNull(),
         col("protein") / col("energy") * 100
    ).otherwise(0.0)
).withColumn(
    "fiber_score",
    when(col("energy").isNotNull() & (col("energy") > 0) & col("fiber").isNotNull(),
         col("fiber") / col("energy") * 100
    ).otherwise(0.0)
).withColumn(
    "vitamin_score",
    when(col("energy").isNotNull() & (col("energy") > 0),
         coalesce(col("vitamin_a"), lit(0)) / 900.0 +  # RDA-based normalization
         coalesce(col("vitamin_c"), lit(0)) / 90.0 +
         coalesce(col("vitamin_e"), lit(0)) / 15.0 +
         coalesce(col("vitamin_k"), lit(0)) / 120.0 +
         coalesce(col("thiamin_b1"), lit(0)) / 1.2 +
         coalesce(col("riboflavin_b2"), lit(0)) / 1.3 +
         coalesce(col("niacin_b3"), lit(0)) / 16.0 +
         coalesce(col("vitamin_b6"), lit(0)) / 1.7 +
         coalesce(col("folate"), lit(0)) / 400.0 +
         coalesce(col("vitamin_b12"), lit(0)) / 2.4
    ).otherwise(0.0)
).withColumn(
    "mineral_score",
    when(col("energy").isNotNull() & (col("energy") > 0),
         coalesce(col("calcium"), lit(0)) / 1000.0 +
         coalesce(col("iron"), lit(0)) / 18.0 +
         coalesce(col("magnesium"), lit(0)) / 400.0 +
         coalesce(col("phosphorus"), lit(0)) / 700.0 +
         coalesce(col("potassium"), lit(0)) / 4700.0 +
         coalesce(col("zinc"), lit(0)) / 11.0 +
         coalesce(col("copper"), lit(0)) / 0.9 +
         coalesce(col("manganese"), lit(0)) / 2.3 +
         coalesce(col("selenium"), lit(0)) / 55.0
    ).otherwise(0.0)
).withColumn(
    "nutrition_density_score",
    when(col("energy").isNotNull() & (col("energy") > 0),
         col("protein_score") * 0.3 +
         col("fiber_score") * 0.2 +
         col("vitamin_score") * 0.25 +
         col("mineral_score") * 0.25
    ).otherwise(0.0)
).filter(
    col("energy").isNotNull() & 
    (col("energy") > 0) &
    col("food_description").isNotNull()
)

# Get top 10 most nutritious foods
top_10_nutritious = df_nutrition_score.select(
    "fdc_id",
    "food_description",
    "food_type",
    spark_round(col("energy"), 1).alias("energy_kcal"),
    spark_round(col("protein"), 2).alias("protein_g"),
    spark_round(col("fiber"), 2).alias("fiber_g"),
    spark_round(col("vitamin_c"), 2).alias("vitamin_c_mg"),
    spark_round(col("calcium"), 2).alias("calcium_mg"),
    spark_round(col("iron"), 2).alias("iron_mg"),
    spark_round(col("nutrition_density_score"), 3).alias("nutrition_score")
).orderBy(desc("nutrition_density_score")).limit(10)

print("=" * 80)
print("TOP 10 MOST NUTRITIOUS FOODS (by nutrition density score)")
print("=" * 80)
top_10_nutritious.show(10, truncate=False)
# Out:
# ...
# TOP 10 MOST NUTRITIOUS FOODS (by nutrition density score)
# ...
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+-----------+---------+-------+------------+----------+-------+---------------+
# |fdc_id |food_description                                                                                                                                               |food_type   |energy_kcal|protein_g|fiber_g|vitamin_c_mg|calcium_mg|iron_mg|nutrition_score|
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+-----------+---------+-------+------------+----------+-------+---------------+
# ...

# %% [markdown]
# ## 8. Food Statistics: Top Nutrient Foods Per Portion

# %%
# Calculate nutrients per portion using food_portion data
# food_portion contains gram_weight which represents the weight of one portion

df_food_portion_clean = df_food_portion.select(
    col("fdc_id"),
    col("amount").alias("portion_amount"),
    col("gram_weight").alias("portion_grams"),
    col("measure_unit_id")
).filter(
    col("gram_weight").isNotNull() & 
    (col("gram_weight") > 0) &
    col("fdc_id").isNotNull()
)

# Join with measure_unit to get portion description
df_measure_unit_clean = df_measure_unit.select(
    col("id").alias("measure_unit_id"),
    col("name").alias("measure_unit_name")
)

df_portion_with_unit = df_food_portion_clean.join(
    df_measure_unit_clean,
    on="measure_unit_id",
    how="left"
).withColumn(
    "portion_description",
    when(col("measure_unit_name").isNotNull(),
         concat_ws(" ", col("portion_amount"), col("measure_unit_name"))
    ).otherwise(concat_ws(" ", col("portion_amount"), lit("units")))
)

# Join nutritional profiles with portion data
df_nutrients_per_portion = df_final_profile.join(
    df_portion_with_unit,
    on="fdc_id",
    how="inner"
).withColumn(
    # Calculate nutrients per portion (nutrients per 100g * portion_grams / 100)
    "protein_per_portion",
    when(col("protein").isNotNull() & col("portion_grams").isNotNull(),
         col("protein") * col("portion_grams") / 100.0
    ).otherwise(None)
).withColumn(
    "fiber_per_portion",
    when(col("fiber").isNotNull() & col("portion_grams").isNotNull(),
         col("fiber") * col("portion_grams") / 100.0
    ).otherwise(None)
).withColumn(
    "vitamin_c_per_portion",
    when(col("vitamin_c").isNotNull() & col("portion_grams").isNotNull(),
         col("vitamin_c") * col("portion_grams") / 100.0
    ).otherwise(None)
).withColumn(
    "calcium_per_portion",
    when(col("calcium").isNotNull() & col("portion_grams").isNotNull(),
         col("calcium") * col("portion_grams") / 100.0
    ).otherwise(None)
).withColumn(
    "iron_per_portion",
    when(col("iron").isNotNull() & col("portion_grams").isNotNull(),
         col("iron") * col("portion_grams") / 100.0
    ).otherwise(None)
).withColumn(
    "energy_per_portion",
    when(col("energy").isNotNull() & col("portion_grams").isNotNull(),
         col("energy") * col("portion_grams") / 100.0
    ).otherwise(None)
)

# Get top 5 foods per key nutrient per portion
print("=" * 80)
print("TOP 5 FOODS BY PROTEIN PER PORTION")
print("=" * 80)
top_5_protein = df_nutrients_per_portion.select(
    "food_description",
    "portion_description",
    spark_round(col("portion_grams"), 1).alias("portion_grams"),
    spark_round(col("protein_per_portion"), 2).alias("protein_per_portion_g"),
    spark_round(col("energy_per_portion"), 1).alias("energy_per_portion_kcal")
).filter(
    col("protein_per_portion").isNotNull()
).orderBy(desc("protein_per_portion")).limit(5)
top_5_protein.show(5, truncate=False)

print("\n" + "=" * 80)
print("TOP 5 FOODS BY FIBER PER PORTION")
print("=" * 80)
top_5_fiber = df_nutrients_per_portion.select(
    "food_description",
    "portion_description",
    spark_round(col("portion_grams"), 1).alias("portion_grams"),
    spark_round(col("fiber_per_portion"), 2).alias("fiber_per_portion_g"),
    spark_round(col("energy_per_portion"), 1).alias("energy_per_portion_kcal")
).filter(
    col("fiber_per_portion").isNotNull()
).orderBy(desc("fiber_per_portion")).limit(5)
top_5_fiber.show(5, truncate=False)

print("\n" + "=" * 80)
print("TOP 5 FOODS BY VITAMIN C PER PORTION")
print("=" * 80)
top_5_vitamin_c = df_nutrients_per_portion.select(
    "food_description",
    "portion_description",
    spark_round(col("portion_grams"), 1).alias("portion_grams"),
    spark_round(col("vitamin_c_per_portion"), 2).alias("vitamin_c_per_portion_mg"),
    spark_round(col("energy_per_portion"), 1).alias("energy_per_portion_kcal")
).filter(
    col("vitamin_c_per_portion").isNotNull()
).orderBy(desc("vitamin_c_per_portion")).limit(5)
top_5_vitamin_c.show(5, truncate=False)

print("\n" + "=" * 80)
print("TOP 5 FOODS BY CALCIUM PER PORTION")
print("=" * 80)
top_5_calcium = df_nutrients_per_portion.select(
    "food_description",
    "portion_description",
    spark_round(col("portion_grams"), 1).alias("portion_grams"),
    spark_round(col("calcium_per_portion"), 2).alias("calcium_per_portion_mg"),
    spark_round(col("energy_per_portion"), 1).alias("energy_per_portion_kcal")
).filter(
    col("calcium_per_portion").isNotNull()
).orderBy(desc("calcium_per_portion")).limit(5)
top_5_calcium.show(5, truncate=False)

print("\n" + "=" * 80)
print("TOP 5 FOODS BY IRON PER PORTION")
print("=" * 80)
top_5_iron = df_nutrients_per_portion.select(
    "food_description",
    "portion_description",
    spark_round(col("portion_grams"), 1).alias("portion_grams"),
    spark_round(col("iron_per_portion"), 2).alias("iron_per_portion_mg"),
    spark_round(col("energy_per_portion"), 1).alias("energy_per_portion_kcal")
).filter(
    col("iron_per_portion").isNotNull()
).orderBy(desc("iron_per_portion")).limit(5)
top_5_iron.show(5, truncate=False)
# Out:
# ...
# TOP 5 FOODS BY PROTEIN PER PORTION
# ...
# +--------------------------------------------------------------------------------------------------------------+-------------------+-------------+---------------------+-----------------------+
# |food_description                                                                                              |portion_description|portion_grams|protein_per_portion_g|energy_per_portion_kcal|
# +--------------------------------------------------------------------------------------------------------------+-------------------+-------------+---------------------+-----------------------+
# |Beef, round, eye of round roast, boneless, separable lean only, trimmed to 0" fat, all grades, cooked, roasted|1.0 undetermined   |346.0        |103.28               |2352.8                 |
# ...

# %% [markdown]
# ## 9. Menu Generation Based on Dietary Restrictions and Allergies

# %% [markdown]
# ### Recipe Data Sampling and Parquet Conversion
#
# To work with limited resources, we:
# 1. **Convert CSV to Parquet** (one-time operation) - More efficient format for Spark
# 2. **Sample recipes** - Create a smaller subset (default: 50,000 recipes) for faster processing
# 3. **Load sampled data** - Use the sampled parquet file for all menu generation
#
# **Note**: Adjust `target_recipe_count` in the cell below based on your resources:
# - **Limited resources**: 10,000-50,000 recipes
# - **Moderate resources**: 50,000-200,000 recipes
# - **Full dataset**: All recipes (~2.2M+)

# %% [markdown]
# ### Alternative CSV Conversion Method
#
# **If cell 12 fails**, use this cell instead. It uses the same pandas-based approach as `convert_csvs_to_parquet.py`:
# - Uses `low_memory=False` for better handling
# - Uses Python engine with `on_bad_lines='skip'` for error handling
# - Reads in smaller chunks (50,000 rows) for better memory management

# %%
# Alternative CSV to Parquet conversion (use if cell 12 fails)
# This uses pandas approach similar to convert_csvs_to_parquet.py
import os
from pathlib import Path
import pandas as pd

recipes_csv_path = "data/2_231_151_recipes_data.csv"
recipes_parquet_path = "data/recipes_data.parquet"

if not os.path.exists(recipes_parquet_path):
    print("=" * 80)
    print("CONVERTING RECIPES CSV TO PARQUET (Alternative Method)")
    print("=" * 80)

    if not os.path.exists(recipes_csv_path):
        print(f"❌ Error: CSV file not found at {recipes_csv_path}")
    else:
        print(f"Reading CSV from: {recipes_csv_path}")
        print("Reading CSV file (this may take a while for large files)...")

        try:
            chunk_size = 50000
            chunks = []
            total_rows = 0

            print(f"Reading CSV in chunks of {chunk_size:,} rows...")

            # Read CSV in chunks with proper error handling
            # Note: low_memory is not supported with Python engine, so we omit it
            for chunk_idx, chunk in enumerate(pd.read_csv(
                recipes_csv_path,
                chunksize=chunk_size,
                on_bad_lines='skip',  # Skip problematic lines
                engine='python'  # Use Python engine for better error handling
            ), start=1):
                chunks.append(chunk)
                total_rows += len(chunk)
                if chunk_idx % 20 == 0:
                    print(f"  Processed {chunk_idx} chunks ({total_rows:,} rows)...")

            print(f"Total chunks read: {len(chunks)}")
            print(f"Total rows: {total_rows:,}")
            print("Concatenating chunks...")

            df_full = pd.concat(chunks, ignore_index=True)
            print(f"Final DataFrame shape: {df_full.shape}")

            Path(recipes_parquet_path).parent.mkdir(parents=True, exist_ok=True)

            print(f"Writing parquet to: {recipes_parquet_path}...")
            df_full.to_parquet(recipes_parquet_path, engine="pyarrow", index=False)

            if os.path.exists(recipes_parquet_path):
                file_size = os.path.getsize(recipes_parquet_path) / (1024 * 1024)
                print(f"[OK] Converted to parquet successfully!")
                print(f"   File: {recipes_parquet_path}")
                print(f"   Size: {file_size:.2f} MB")
                print(f"   Rows: {len(df_full):,}")
                print(f"   Columns: {len(df_full.columns)}")
            else:
                print(f"❌ Error: Parquet file was not created")

        except Exception as e:
            print(f"❌ Error converting CSV to parquet: {e}")
            import traceback
            traceback.print_exc()
else:
    print(f"[OK] Parquet file already exists: {recipes_parquet_path}")
# Out:
# [OK] Parquet file already exists: data/recipes_data.parquet

# %%
# Define dietary restrictions and forbidden/allergenic ingredients
import json
from pyspark.sql.functions import col, when, lit, array_contains, lower, regexp_replace, split, explode, size, array_distinct, collect_list, concat_ws
from pyspark.sql.types import ArrayType, StringType

# Dietary restrictions mapping: restriction_name -> list of forbidden ingredients/keywords
DIETARY_RESTRICTIONS = {
    "vegan": {
        "forbidden": [
            "meat", "beef", "pork", "chicken", "turkey", "lamb", "fish", "seafood", 
            "milk", "cheese", "butter", "cream", "yogurt", "eggs", "egg", 
            "honey", "gelatin", "whey", "casein", "lactose", "dairy"
        ],
        "description": "No animal products including meat, dairy, eggs, or honey"
    },
    "vegetarian": {
        "forbidden": [
            "meat", "beef", "pork", "chicken", "turkey", "lamb", "fish", "seafood",
            "gelatin", "rennet"
        ],
        "description": "No meat or fish, but allows dairy and eggs"
    },
    "kosher": {
        "forbidden": [
            "pork", "shellfish", "shrimp", "crab", "lobster", "mixing meat and dairy",
            "non-kosher meat", "bacon", "ham"
        ],
        "description": "Jewish dietary laws - no pork, shellfish, or mixing meat with dairy"
    },
    "halal": {
        "forbidden": [
            "pork", "alcohol", "wine", "beer", "non-halal meat", "bacon", "ham",
            "gelatin from pork", "lard"
        ],
        "description": "Islamic dietary laws - no pork, alcohol, or non-halal meat"
    },
    "gluten_free": {
        "forbidden": [
            "wheat", "barley", "rye", "flour", "bread", "pasta", "gluten",
            "semolina", "couscous", "bulgur", "spelt", "farro"
        ],
        "description": "No gluten-containing grains (wheat, barley, rye)"
    },
    "lactose_intolerant": {
        "forbidden": [
            "milk", "cheese", "butter", "cream", "yogurt", "lactose", "whey",
            "casein", "dairy", "sour cream", "buttermilk"
        ],
        "description": "No lactose-containing dairy products"
    },
    "nut_allergy": {
        "forbidden": [
            "peanut", "almond", "walnut", "cashew", "pistachio", "hazelnut",
            "pecan", "macadamia", "brazil nut", "nuts", "nut"
        ],
        "description": "No tree nuts or peanuts"
    },
    "shellfish_allergy": {
        "forbidden": [
            "shrimp", "crab", "lobster", "mussel", "oyster", "clam", "scallop",
            "shellfish", "prawn", "crayfish"
        ],
        "description": "No shellfish or crustaceans"
    },
    "egg_allergy": {
        "forbidden": [
            "egg", "eggs", "mayonnaise", "meringue", "custard"
        ],
        "description": "No eggs or egg-containing products"
    }
}

print("=" * 80)
print("DIETARY RESTRICTIONS DEFINED")
print("=" * 80)
for restriction, details in DIETARY_RESTRICTIONS.items():
    print(f"\n{restriction.upper()}:")
    print(f"  Description: {details['description']}")
    print(f"  Forbidden ingredients: {', '.join(details['forbidden'][:5])}... ({len(details['forbidden'])} total)")
# Out:
# ...
# DIETARY RESTRICTIONS DEFINED
# ...
#
# VEGAN:
#   Description: No animal products including meat, dairy, eggs, or honey
#   Forbidden ingredients: meat, beef, pork, chicken, turkey... (21 total)
#
# VEGETARIAN:
#   Description: No meat or fish, but allows dairy and eggs
#   Forbidden ingredients: meat, beef, pork, chicken, turkey... (10 total)
#
# KOSHER:
#   Description: Jewish dietary laws - no pork, shellfish, or mixing meat with dairy
#   Forbidden ingredients: pork, shellfish, shrimp, crab, lobster... (9 total)
#
# HALAL:
#   Description: Islamic dietary laws - no pork, alcohol, or non-halal meat
#   Forbidden ingredients: pork, alcohol, wine, beer, non-halal meat... (9 total)
#
# GLUTEN_FREE:
#   Description: No gluten-containing grains (wheat, barley, rye)
#   Forbidden ingredients: wheat, barley, rye, flour, bread... (12 total)
#
# LACTOSE_INTOLERANT:
#   Description: No lactose-containing dairy products
#   Forbidden ingredients: milk, cheese, butter, cream, yogurt... (11 total)
# ...

# %%
# Step 1: Convert recipes CSV to Parquet (if not already done)
# This step only needs to be run once
import os
from pathlib import Path

recipes_csv_path = "data/2_231_151_recipes_data.csv"
recipes_parquet_path = "data/recipes_data.parquet"
sampled_recipes_path = "sampled_dataset/recipes_data.parquet"

# Check if parquet already exists (parquet creates directories, check for _SUCCESS file or directory)
parquet_exists = os.path.exists(recipes_parquet_path) or os.path.exists(f"{recipes_parquet_path}/_SUCCESS")
sampled_exists = os.path.exists(sampled_recipes_path) or os.path.exists(f"{sampled_recipes_path}/_SUCCESS")

# Check if parquet already exists, if not convert CSV to parquet
if not parquet_exists:
    print("=" * 80)
    print("CONVERTING RECIPES CSV TO PARQUET")
    print("=" * 80)
    print(f"Reading CSV from: {recipes_csv_path}")
    
    # Use Spark to read CSV and write parquet (more memory efficient for large files)
    df_recipes_raw = spark.read.option("header", "true").option("escape", "\"").csv(recipes_csv_path)
    
    print(f"Total recipes in CSV: {df_recipes_raw.count():,}")
    print(f"Writing parquet to: {recipes_parquet_path}...")
    
    try:
        df_recipes_raw.repartition(1).write.mode("overwrite").parquet(recipes_parquet_path)
        print(f"[OK] Converted to parquet successfully!")
    except Exception as e:
        print(f"[WARN]  Spark write failed, trying pandas fallback...")
        print(f"Error: {str(e)[:200]}...")
        import pandas as pd
        
        # Read in chunks for large files (using robust approach similar to convert_csvs_to_parquet.py)
        chunk_size = 50000  # Smaller chunks for better memory management
        chunks = []
        total_rows = 0
        print("Reading CSV in chunks (this may take a while)...")
        print(f"Using Python engine with error handling (chunksize={chunk_size:,})...")
        
        try:
            # Use Python engine with proper error handling
            # Note: low_memory is not supported with Python engine, so we omit it
            for chunk_idx, chunk in enumerate(pd.read_csv(
                recipes_csv_path,
                chunksize=chunk_size,
                on_bad_lines='skip',  # Skip problematic lines
                engine='python'  # Use Python engine for better error handling
            ), start=1):
                chunks.append(chunk)
                total_rows += len(chunk)
                if chunk_idx % 20 == 0:
                    print(f"  Processed {chunk_idx} chunks ({total_rows:,} rows)...")
            
            print(f"Total chunks read: {len(chunks)}")
            print(f"Total rows: {total_rows:,}")
            print("Concatenating chunks...")
            
            df_full = pd.concat(chunks, ignore_index=True)
            print(f"Final DataFrame shape: {df_full.shape}")
            
            Path(recipes_parquet_path).parent.mkdir(parents=True, exist_ok=True)
            
            print(f"Writing parquet to: {recipes_parquet_path}...")
            df_full.to_parquet(recipes_parquet_path, engine="pyarrow", index=False)
            
            if os.path.exists(recipes_parquet_path):
                file_size = os.path.getsize(recipes_parquet_path) / (1024 * 1024)
                print(f"[OK] Converted to parquet successfully!")
                print(f"   File: {recipes_parquet_path}")
                print(f"   Size: {file_size:.2f} MB")
                print(f"   Rows: {len(df_full):,}")
                print(f"   Columns: {len(df_full.columns)}")
            else:
                print(f"❌ Error: Parquet file was not created")
                
        except Exception as e2:
            print(f"❌ Pandas conversion also failed: {e2}")
            import traceback
            traceback.print_exc()
else:
    print(f"[OK] Parquet file already exists: {recipes_parquet_path}")

# Step 2: Sample recipes (if sampled version doesn't exist)
if not sampled_exists:
    print("\n" + "=" * 80)
    print("SAMPLING RECIPES DATA")
    print("=" * 80)
    
    # Adjust target_recipe_count based on available resources
    # For limited resources, use 10,000-50,000 recipes
    # For moderate resources, use 50,000-200,000 recipes
    # For full dataset, use all recipes (2.2M+)
    target_recipe_count = 50000  # Default: moderate sample size
    
    print(f"Target sample size: {target_recipe_count:,} recipes")
    print(f"Reading from: {recipes_parquet_path}")
    
    # Read parquet file
    try:
        df_recipes_full = spark.read.parquet(recipes_parquet_path)
        total_count = df_recipes_full.count()
        print(f"Total recipes available: {total_count:,}")
        
        if total_count > target_recipe_count:
            # Sample using Spark
            sample_fraction = target_recipe_count / total_count
            print(f"Sampling {sample_fraction:.4f} of data...")
            df_recipes_sampled = df_recipes_full.sample(fraction=sample_fraction, seed=42)
            sampled_count = df_recipes_sampled.count()
            print(f"Sampled recipes: {sampled_count:,}")
        else:
            print("Total recipes is less than target, using all recipes")
            df_recipes_sampled = df_recipes_full
            sampled_count = total_count
        
        # Save sampled recipes
        Path(sampled_recipes_path).parent.mkdir(parents=True, exist_ok=True)
        print(f"Writing sampled recipes to: {sampled_recipes_path}...")
        
        try:
            df_recipes_sampled.repartition(1).write.mode("overwrite").parquet(sampled_recipes_path)
            print(f"[OK] Sampled recipes saved using Spark!")
        except Exception as e:
            print(f"[WARN]  Spark write failed: {str(e)[:200]}...")
            print("Trying pandas fallback...")
            import pandas as pd
            
            # Convert to pandas and save as single file
            pdf = df_recipes_sampled.toPandas()
            if len(pdf) == 0:
                raise ValueError("Sampled DataFrame is empty")
            
            # Ensure parent directory exists
            Path(sampled_recipes_path).parent.mkdir(parents=True, exist_ok=True)
            
            # Save as single parquet file (not directory)
            pdf.to_parquet(sampled_recipes_path, engine="pyarrow", index=False)
            
            # Verify file was created
            if os.path.exists(sampled_recipes_path):
                file_size = os.path.getsize(sampled_recipes_path) / (1024 * 1024)
                print(f"[OK] Sampled recipes saved using pandas!")
                print(f"   File: {sampled_recipes_path}")
                print(f"   Size: {file_size:.2f} MB")
                print(f"   Rows: {len(pdf):,}")
                print(f"   Columns: {len(pdf.columns)}")
            else:
                raise RuntimeError("Parquet file was not created")
            
    except Exception as e:
        print(f"[WARN]  Spark read failed: {str(e)[:200]}...")
        print("Trying pandas...")
        import pandas as pd
        
        try:
            df_recipes_full = pd.read_parquet(recipes_parquet_path)
            total_count = len(df_recipes_full)
            print(f"Total recipes available: {total_count:,}")
            
            if total_count == 0:
                raise ValueError("Parquet file is empty")
            
            if total_count > target_recipe_count:
                df_recipes_sampled = df_recipes_full.sample(n=target_recipe_count, random_state=42)
                sampled_count = len(df_recipes_sampled)
                print(f"Sampled recipes: {sampled_count:,}")
            else:
                df_recipes_sampled = df_recipes_full
                sampled_count = total_count
            
            Path(sampled_recipes_path).parent.mkdir(parents=True, exist_ok=True)
            df_recipes_sampled.to_parquet(sampled_recipes_path, engine="pyarrow", index=False)
            
            # Verify file was created
            if os.path.exists(sampled_recipes_path):
                file_size = os.path.getsize(sampled_recipes_path) / (1024 * 1024)
                print(f"[OK] Sampled recipes saved!")
                print(f"   File: {sampled_recipes_path}")
                print(f"   Size: {file_size:.2f} MB")
                print(f"   Rows: {sampled_count:,}")
                print(f"   Columns: {len(df_recipes_sampled.columns)}")
            else:
                raise RuntimeError("Parquet file was not created")
        except Exception as e2:
            print(f"❌ Pandas sampling also failed: {e2}")
            import traceback
            traceback.print_exc()
            raise
else:
    print(f"[OK] Sampled recipes already exist: {sampled_recipes_path}")

# Step 3: Load sampled recipes data
print("\n" + "=" * 80)
print("LOADING SAMPLED RECIPES DATA")
print("=" * 80)

# Load from sampled parquet file
# Handle both Spark directory structure and pandas single file
df_recipes_raw = None
loaded_via_pandas = False

try:
    # Try Spark read first (expects directory structure)
    df_recipes_raw = spark.read.parquet(sampled_recipes_path)
    count = df_recipes_raw.count()
    if count > 0:
        print(f"Loaded recipes from parquet: {count:,}")
    else:
        raise ValueError("Parquet file appears to be empty")
except Exception as e:
    print(f"[WARN]  Spark read failed: {str(e)[:200]}...")
    print("Trying pandas read...")
    import pandas as pd
    
    # Try reading as single file first (pandas format)
    try:
        pdf = pd.read_parquet(sampled_recipes_path)
        if len(pdf) == 0 or len(pdf.columns) == 0:
            raise ValueError("Parquet file is empty or has no columns")
        df_recipes_raw = spark.createDataFrame(pdf)
        print(f"Loaded recipes via pandas: {len(pdf):,} rows, {len(pdf.columns)} columns")
        loaded_via_pandas = True
    except Exception as e2:
        print(f"[WARN]  Pandas read also failed: {str(e2)[:200]}...")
        print("Attempting to regenerate sampled file...")
        
        # Regenerate the sampled file
        try:
            # Use default target (same as sampling step)
            regenerate_target_count = 50000  # Default: moderate sample size
            
            # Read full parquet
            df_recipes_full = spark.read.parquet(recipes_parquet_path)
            total_count = df_recipes_full.count()
            print(f"Total recipes available: {total_count:,}")
            
            if total_count > regenerate_target_count:
                sample_fraction = regenerate_target_count / total_count
                df_recipes_sampled = df_recipes_full.sample(fraction=sample_fraction, seed=42)
            else:
                df_recipes_sampled = df_recipes_full
            
            # Save using pandas (single file format)
            Path(sampled_recipes_path).parent.mkdir(parents=True, exist_ok=True)
            pdf_sampled = df_recipes_sampled.toPandas()
            pdf_sampled.to_parquet(sampled_recipes_path, engine="pyarrow", index=False)
            
            # Load the regenerated file
            pdf = pd.read_parquet(sampled_recipes_path)
            df_recipes_raw = spark.createDataFrame(pdf)
            print(f"[OK] Regenerated and loaded sampled recipes: {len(pdf):,} rows")
            loaded_via_pandas = True
        except Exception as e3:
            print(f"❌ Failed to regenerate sampled file: {e3}")
            raise

if df_recipes_raw is None:
    raise RuntimeError("Failed to load sampled recipes data")

# Parse JSON arrays in ingredients and NER columns
from pyspark.sql.functions import from_json, regexp_replace as spark_regexp_replace

# Clean and parse ingredients column (it's stored as JSON array string)
df_recipes = df_recipes_raw.select(
    col("title"),
    col("ingredients"),
    col("directions"),
    col("link"),
    col("source"),
    col("NER"),
    col("site")
).filter(
    col("title").isNotNull() & 
    col("ingredients").isNotNull()
)

# Parse ingredients JSON array
# Ingredients are stored as: ["ingredient1", "ingredient2", ...]
# We need to extract them properly
def parse_json_array(col_name):
    """Parse JSON array string to Spark array"""
    # Remove brackets and quotes, then split
    return split(
        regexp_replace(
            regexp_replace(col(col_name), "^\\[", ""),
            "\\]$", ""
        ),
        '", "'
    )

# For ingredients, split by comma after cleaning
df_recipes_parsed = df_recipes.withColumn(
    "ingredients_clean",
    regexp_replace(
        regexp_replace(
            regexp_replace(col("ingredients"), "^\\[", ""),
            "\\]$", ""
        ),
        '"', ""
    )
).withColumn(
    "ingredients_list",
    split(col("ingredients_clean"), ", ")
).withColumn(
    "ingredients_lower",
    split(lower(col("ingredients_clean")), ", ")
)

# Also parse NER (Named Entity Recognition) column which contains key ingredients
df_recipes_parsed = df_recipes_parsed.withColumn(
    "ner_clean",
    regexp_replace(
        regexp_replace(
            regexp_replace(col("NER"), "^\\[", ""),
            "\\]$", ""
        ),
        '"', ""
    )
).withColumn(
    "ner_list",
    split(lower(col("ner_clean")), ", ")
)

print(f"\nTotal recipes loaded: {df_recipes_parsed.count():,}")
print(f"\nSample recipe:")
df_recipes_parsed.select("title", "ingredients_list", "ner_list").show(3, truncate=False)
# Out:
# [OK] Parquet file already exists: data/recipes_data.parquet
# [OK] Sampled recipes already exist: sampled_dataset/recipes_data.parquet
#
# ...
# LOADING SAMPLED RECIPES DATA
# ...
# Loaded recipes from parquet: 49,934
#
# Total recipes loaded: 49,934
#
# Sample recipe:
# +----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------+
# ...

# %%
# Function to check if recipe contains forbidden ingredients
def check_dietary_restriction(ingredients_array, forbidden_keywords):
    """
    Check if any forbidden keyword appears in the ingredients list
    Returns True if recipe is COMPLIANT (no forbidden ingredients found)
    """
    # Flatten ingredients array and check each ingredient
    ingredients_str = concat_ws(" ", ingredients_array).lower()
    
    # Check if any forbidden keyword is in the ingredients string
    is_compliant = True
    for keyword in forbidden_keywords:
        if keyword.lower() in ingredients_str:
            is_compliant = False
            break
    
    return is_compliant

# Create UDF for checking dietary restrictions
from pyspark.sql.types import BooleanType

def create_restriction_checker(forbidden_keywords):
    """Create a UDF that checks if recipe is compliant with restriction"""
    def check_restriction(ingredients_list):
        if ingredients_list is None:
            return False
        ingredients_str = " ".join([str(ing).lower() for ing in ingredients_list])
        for keyword in forbidden_keywords:
            if keyword.lower() in ingredients_str:
                return False
        return True
    
    return spark.udf.register("check_restriction", check_restriction, BooleanType())

# Filter recipes for each dietary restriction
dietary_menus = {}

for restriction_name, restriction_details in DIETARY_RESTRICTIONS.items():
    print(f"\n{'='*80}")
    print(f"Filtering recipes for: {restriction_name.upper()}")
    print(f"{'='*80}")
    
    forbidden = restriction_details["forbidden"]
    
    # Create filter condition: recipe is compliant if no forbidden keywords found
    filter_condition = lit(True)
    for keyword in forbidden:
        # Check both ingredients_list and ner_list
        filter_condition = filter_condition & (
            ~lower(concat_ws(" ", col("ingredients_list"))).contains(keyword.lower()) &
            ~lower(concat_ws(" ", col("ner_list"))).contains(keyword.lower())
        )
    
    df_filtered = df_recipes_parsed.filter(filter_condition)
    
    count = df_filtered.count()
    dietary_menus[restriction_name] = df_filtered
    
    print(f"Compliant recipes found: {count:,}")
    print(f"Compliance rate: {count / df_recipes_parsed.count() * 100:.2f}%")
    
    if count > 0:
        print(f"\nSample compliant recipes:")
        df_filtered.select("title", "ingredients_list").show(3, truncate=False)
# Out:
# ...
# Filtering recipes for: VEGAN
# ...
# Compliant recipes found: 9,301
# Compliance rate: 18.63%
#
# Sample compliant recipes:
# +----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |title                             |ingredients_list                                                                                                                                                                                                                                                                                                                        |
# ...

# %%
# Generate sample menus for each dietary restriction category
# A menu consists of multiple recipes (e.g., breakfast, lunch, dinner)

import random
from pyspark.sql.functions import rand

print("=" * 80)
print("GENERATING MENUS FOR EACH DIETARY RESTRICTION CATEGORY")
print("=" * 80)

MENU_SIZE = 5  # Number of recipes per menu

for restriction_name, df_menu_recipes in dietary_menus.items():
    count = df_menu_recipes.count()
    
    if count == 0:
        print(f"\n{restriction_name.upper()}: No compliant recipes found")
        continue
    
    # Get random sample of recipes for the menu
    sample_size = min(MENU_SIZE, count)
    df_menu = df_menu_recipes.orderBy(rand()).limit(sample_size)
    
    print(f"\n{'='*80}")
    print(f"MENU FOR: {restriction_name.upper()}")
    print(f"Description: {DIETARY_RESTRICTIONS[restriction_name]['description']}")
    print(f"Total compliant recipes available: {count:,}")
    print(f"Menu size: {sample_size} recipes")
    print(f"{'='*80}")
    
    menu_recipes = df_menu.select("title", "ingredients_list", "directions", "link").collect()
    
    for idx, recipe in enumerate(menu_recipes, 1):
        print(f"\n{idx}. {recipe['title']}")
        print(f"   Ingredients: {', '.join(recipe['ingredients_list'][:5])}...")
        if recipe['link']:
            print(f"   Source: {recipe['link']}")
    
    print(f"\n{'─'*80}")
# Out:
# ...
# GENERATING MENUS FOR EACH DIETARY RESTRICTION CATEGORY
# ...
#
# ...
# MENU FOR: VEGAN
# Description: No animal products including meat, dairy, eggs, or honey
# Total compliant recipes available: 9,301
# Menu size: 5 recipes
# ...
#
# 1. Peanut Brittle
#    Ingredients: 2 c. sugar, 1 c. light corn syrup, 1/2 c. water, 1 c. margarine, 2 c. peanuts...
#    Source: www.cookbooks.com/Recipe-Details.aspx?id=957681
#
# 2. Lemon Couscous
#    Ingredients: 3/4 cup couscous, 2 tbsp chopped fresh parsley, 1 tsp grated lemon zest, 1 tbsp fresh lemon juice, 1 tbsp olive oil...
#    Source: cookpad.com/us/recipes/339956-lemon-couscous
#
# 3. Boiled Raisin Cake I
#    Ingredients: 2 cups raisins, 2 cups water, 1/2 cup vegetable oil, 1 cup cold water, 2 cups white sugar...
#    Source: www.allrecipes.com/recipe/7263/boiled-raisin-cake-i/
#
# 4. Sweet Glazed Carrots
#    Ingredients: 8 carrots, peeled, diagonally sliced Target 2 lb For $3.00 thru 02/06, 1/2 cup KRAFT Classic CATALINA Dressing, 2 Tbsp. brown sugar...
# ...

# %%
# Create comprehensive menu summary with statistics
from pyspark.sql.functions import count as spark_count, avg, min as spark_min, max as spark_max, desc

print("=" * 80)
print("MENU GENERATION SUMMARY STATISTICS")
print("=" * 80)

summary_data = []

for restriction_name, df_menu_recipes in dietary_menus.items():
    count = df_menu_recipes.count()
    total_recipes = df_recipes_parsed.count()
    compliance_rate = (count / total_recipes * 100) if total_recipes > 0 else 0
    
    summary_data.append({
        "restriction": restriction_name,
        "compliant_recipes": count,
        "total_recipes": total_recipes,
        "compliance_rate": compliance_rate,
        "description": DIETARY_RESTRICTIONS[restriction_name]["description"]
    })

# Create summary DataFrame
import pandas as pd
df_summary_pd = pd.DataFrame(summary_data)

# Sort by compliance rate
df_summary_pd = df_summary_pd.sort_values("compliance_rate", ascending=False)

print("\nCompliance Statistics by Dietary Restriction:")
print("=" * 80)
print(f"{'Dietary Restriction':<30} {'Compliant Recipes':<20} {'Compliance Rate (%)':<20}")
print("=" * 80)
for _, row in df_summary_pd.iterrows():
    print(f"{row['restriction']:<30} {row['compliant_recipes']:<20,} {row['compliance_rate']:<20.2f}")

print("\n" + "=" * 80)
print("DETAILED BREAKDOWN")
print("=" * 80)
for _, row in df_summary_pd.iterrows():
    print(f"\n{row['restriction'].upper()}:")
    print(f"  Description: {row['description']}")
    print(f"  Compliant recipes: {row['compliant_recipes']:,}")
    print(f"  Total recipes: {row['total_recipes']:,}")
    print(f"  Compliance rate: {row['compliance_rate']:.2f}%")
# Out:
# ...
# MENU GENERATION SUMMARY STATISTICS
# ...
#
# Compliance Statistics by Dietary Restriction:
# ...
# Dietary Restriction            Compliant Recipes    Compliance Rate (%)
# ...
# shellfish_allergy              47,947               96.02
# kosher                         42,730               85.57
# halal                          41,246               82.60
# nut_allergy                    37,891               75.88
# vegetarian                     36,343               72.78
# egg_allergy                    32,814               65.71
# gluten_free                    32,474               65.03
# lactose_intolerant             18,479               37.01
# vegan                          9,301                18.63
#
# ...
# DETAILED BREAKDOWN
# ...
#
# SHELLFISH_ALLERGY:
#   Description: No shellfish or crustaceans
#   Compliant recipes: 47,947
#   Total recipes: 49,934
#   Compliance rate: 96.02%
#
# KOSHER:
#   Description: Jewish dietary laws - no pork, shellfish, or mixing meat with dairy
# ...

# %%
# Save filtered menus to parquet files for each dietary restriction
output_dir = "D:/1-master/2024-2026/1-ISST/BigDataAnalitics/1-labs/fii-bda/FII-BDA/output/menus"
os.makedirs(output_dir, exist_ok=True)

print("=" * 80)
print("SAVING MENUS TO PARQUET FILES")
print("=" * 80)

for restriction_name, df_menu_recipes in dietary_menus.items():
    count = df_menu_recipes.count()
    
    if count == 0:
        print(f"\n[WARN]  {restriction_name}: No recipes to save")
        continue
    
    # Select relevant columns for menu
    df_menu_export = df_menu_recipes.select(
        col("title").alias("recipe_title"),
        col("ingredients_list").alias("ingredients"),
        col("ner_list").alias("key_ingredients"),
        col("directions"),
        col("link").alias("recipe_link"),
        col("source"),
        col("site")
    ).withColumn(
        "dietary_restriction",
        lit(restriction_name)
    ).withColumn(
        "restriction_description",
        lit(DIETARY_RESTRICTIONS[restriction_name]["description"])
    )
    
    output_path = f"{output_dir}/{restriction_name}_menu.parquet"
    
    try:
        # Try Spark write first
        df_menu_export.repartition(1).write.mode("overwrite").parquet(output_path)
        print(f"[OK] {restriction_name}: Saved {count:,} recipes to {output_path}")
    except Exception as e:
        print(f"[WARN]  {restriction_name}: Spark write failed, trying pandas fallback...")
        try:
            import pandas as pd
            from pathlib import Path
            
            Path(output_path).mkdir(parents=True, exist_ok=True)
            pdf = df_menu_export.toPandas()
            output_file = f"{output_path}/{restriction_name}_menu.parquet"
            pdf.to_parquet(output_file, engine="pyarrow", index=False)
            print(f"[OK] {restriction_name}: Saved {len(pdf):,} recipes using pandas")
        except Exception as e2:
            print(f"❌ {restriction_name}: Failed to save - {str(e2)[:100]}")

print(f"\n[OK] Menu generation complete! Files saved to: {output_dir}")
# Out:
# ...
# SAVING MENUS TO PARQUET FILES
# ...
# [WARN]  vegan: Spark write failed, trying pandas fallback...
# [OK] vegan: Saved 9,301 recipes using pandas
# [WARN]  vegetarian: Spark write failed, trying pandas fallback...
# [OK] vegetarian: Saved 36,343 recipes using pandas
# [WARN]  kosher: Spark write failed, trying pandas fallback...
# [OK] kosher: Saved 42,730 recipes using pandas
# [WARN]  halal: Spark write failed, trying pandas fallback...
# [OK] halal: Saved 41,246 recipes using pandas
# [WARN]  gluten_free: Spark write failed, trying pandas fallback...
# [OK] gluten_free: Saved 32,474 recipes using pandas
# [WARN]  lactose_intolerant: Spark write failed, trying pandas fallback...
# [OK] lactose_intolerant: Saved 18,479 recipes using pandas
# [WARN]  nut_allergy: Spark write failed, trying pandas fallback...
# [OK] nut_allergy: Saved 37,891 recipes using pandas
# [WARN]  shellfish_allergy: Spark write failed, trying pandas fallback...
# ...

# %%
# Create a combined menu file with all restrictions
print("=" * 80)
print("CREATING COMBINED MENU FILE")
print("=" * 80)

# Combine all menus
menu_dfs = []
for restriction_name, df_menu_recipes in dietary_menus.items():
    if df_menu_recipes.count() > 0:
        df_combined = df_menu_recipes.select(
            col("title").alias("recipe_title"),
            col("ingredients_list").alias("ingredients"),
            col("ner_list").alias("key_ingredients"),
            col("directions"),
            col("link").alias("recipe_link"),
            col("source"),
            col("site")
        ).withColumn(
            "dietary_restriction",
            lit(restriction_name)
        ).withColumn(
            "restriction_description",
            lit(DIETARY_RESTRICTIONS[restriction_name]["description"])
        )
        menu_dfs.append(df_combined)

if menu_dfs:
    from functools import reduce
    df_all_menus = reduce(lambda df1, df2: df1.union(df2), menu_dfs)
    
    combined_output = f"{output_dir}/all_dietary_menus.parquet"
    
    try:
        df_all_menus.repartition(1).write.mode("overwrite").parquet(combined_output)
        print(f"[OK] Combined menu saved: {df_all_menus.count():,} total recipes")
    except Exception as e:
        print(f"[WARN]  Spark write failed, trying pandas fallback...")
        try:
            import pandas as pd
            from pathlib import Path
            
            Path(combined_output).mkdir(parents=True, exist_ok=True)
            pdf = df_all_menus.toPandas()
            output_file = f"{combined_output}/all_dietary_menus.parquet"
            pdf.to_parquet(output_file, engine="pyarrow", index=False)
            print(f"[OK] Combined menu saved using pandas: {len(pdf):,} recipes")
        except Exception as e2:
            print(f"❌ Failed to save combined menu: {str(e2)[:100]}")
    
    # Show sample of combined menu
    print("\nSample from combined menu:")
    df_all_menus.select("recipe_title", "dietary_restriction", "ingredients").show(5, truncate=False)
else:
    print("[WARN]  No menus to combine")
# Out:
# ...
# CREATING COMBINED MENU FILE
# ...
# [WARN]  Spark write failed, trying pandas fallback...
# [OK] Combined menu saved using pandas: 299,225 recipes
#
# Sample from combined menu:
# +----------------------------------+-------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |recipe_title                      |dietary_restriction|ingredients                                                                                                                                                                                                                                                                                                                             |
# ...

# %% [markdown]
# ## 10. Restaurant Menu Generation: Nutritious 3-Course Meals Based on Real User Allergy Statistics

# %%
# Load and analyze food allergy dataset to get statistical distribution
allergy_csv_path = "data/10_002_users-food_allergy.csv"

print("=" * 80)
print("LOADING AND ANALYZING FOOD ALLERGY DATA")
print("=" * 80)

# Load allergy data
df_allergy_raw = spark.read.option("header", "true").csv(allergy_csv_path)

# Filter only allergic users (Allergic == 1)
df_allergic_users = df_allergy_raw.filter(col("Allergic") == "1")

print(f"Total users: {df_allergy_raw.count():,}")
print(f"Allergic users: {df_allergic_users.count():,}")

# Analyze Food_Type distribution
from pyspark.sql.functions import count, desc, round as spark_round

df_allergy_distribution = df_allergic_users.groupBy("Food_Type").agg(
    count("*").alias("user_count"),
    spark_round(count("*") * 100.0 / df_allergic_users.count(), 2).alias("percentage")
).orderBy(desc("user_count"))

print("\n" + "=" * 80)
print("FOOD ALLERGY DISTRIBUTION (from real users)")
print("=" * 80)
df_allergy_distribution.show(truncate=False)

# Map Food_Type to our dietary restrictions
FOOD_TYPE_TO_RESTRICTION = {
    "Gluten": "gluten_free",
    "Eggs": "egg_allergy",
    "Nuts": "nut_allergy",
    "Seafood": "shellfish_allergy",
    "Dairy": "lactose_intolerant"
}

# Collect distribution as dictionary
allergy_distribution = {}
for row in df_allergy_distribution.collect():
    food_type = row["Food_Type"]
    user_count = row["user_count"]
    percentage = row["percentage"]
    
    if food_type in FOOD_TYPE_TO_RESTRICTION:
        restriction = FOOD_TYPE_TO_RESTRICTION[food_type]
        allergy_distribution[restriction] = {
            "user_count": user_count,
            "percentage": percentage,
            "food_type": food_type
        }

print("\n" + "=" * 80)
print("MAPPED ALLERGY DISTRIBUTION TO DIETARY RESTRICTIONS")
print("=" * 80)
for restriction, info in allergy_distribution.items():
    print(f"{restriction}: {info['user_count']:,} users ({info['percentage']}%) - {info['food_type']}")

# Calculate number of meals needed for each restriction (proportional to user distribution)
total_meals_to_generate = 100  # Total number of meal combinations to create
meal_distribution = {}

for restriction, info in allergy_distribution.items():
    meal_count = int(total_meals_to_generate * info["percentage"] / 100)
    meal_distribution[restriction] = meal_count

print("\n" + "=" * 80)
print("MEAL DISTRIBUTION (statistically correct)")
print("=" * 80)
for restriction, meal_count in sorted(meal_distribution.items(), key=lambda x: x[1], reverse=True):
    print(f"{restriction}: {meal_count} meals")
# Out:
# ...
# LOADING AND ANALYZING FOOD ALLERGY DATA
# ...
# Total users: 10,000
# Allergic users: 9,116
#
# ...
# FOOD ALLERGY DISTRIBUTION (from real users)
# ...
# +---------+----------+----------+
# |Food_Type|user_count|percentage|
# +---------+----------+----------+
# |Nuts     |1862      |20.43     |
# |Gluten   |1830      |20.07     |
# |Eggs     |1829      |20.06     |
# |Seafood  |1826      |20.03     |
# |Dairy    |1769      |19.41     |
# +---------+----------+----------+
#
#
# ...
# MAPPED ALLERGY DISTRIBUTION TO DIETARY RESTRICTIONS
# ...
# nut_allergy: 1,862 users (20.43%) - Nuts
# gluten_free: 1,830 users (20.07%) - Gluten
# egg_allergy: 1,829 users (20.06%) - Eggs
# shellfish_allergy: 1,826 users (20.03%) - Seafood
# lactose_intolerant: 1,769 users (19.41%) - Dairy
#
# ...
# MEAL DISTRIBUTION (statistically correct)
# ...
# nut_allergy: 20 meals
# gluten_free: 20 meals
# egg_allergy: 20 meals
# shellfish_allergy: 20 meals
# lactose_intolerant: 19 meals

# %%
# Categorize recipes into starter, main_dish, and dessert
# This is a simplified categorization based on recipe titles and ingredients

from pyspark.sql.functions import when, lower, array_contains

print("=" * 80)
print("CATEGORIZING RECIPES INTO STARTER, MAIN DISH, AND DESSERT")
print("=" * 80)

# Keywords for categorization
starter_keywords = ["soup", "salad", "appetizer", "starter", "dip", "spread", 
                   "bruschetta", "crostini", "salsa", "guacamole", "hummus"]
main_keywords = ["main", "entree", "dinner", "lunch", "chicken", "beef", "pork",
                "fish", "pasta", "rice", "stew", "curry", "casserole", "roast"]
dessert_keywords = ["dessert", "cake", "pie", "cookie", "brownie", "pudding",
                   "ice cream", "mousse", "tart", "sweet", "chocolate", "sugar"]

# Categorize recipes
# Build regex patterns
starter_pattern = "|".join([f".*{kw}.*" for kw in starter_keywords])
dessert_pattern = "|".join([f".*{kw}.*" for kw in dessert_keywords])
main_pattern = "|".join([f".*{kw}.*" for kw in main_keywords])

df_recipes_categorized = df_recipes_parsed.withColumn(
    "category",
    when(
        lower(col("title")).rlike(starter_pattern),
        lit("starter")
    ).when(
        lower(col("title")).rlike(dessert_pattern),
        lit("dessert")
    ).when(
        lower(col("title")).rlike(main_pattern),
        lit("main_dish")
    ).otherwise(
        # Fallback: categorize by ingredients
        when(
            lower(concat_ws(" ", col("ingredients_list"))).rlike(".*(sugar|chocolate|vanilla|flour|butter).*") &
            ~lower(concat_ws(" ", col("ingredients_list"))).rlike(".*(chicken|beef|pork|fish).*"),
            lit("dessert")
        ).when(
            lower(concat_ws(" ", col("ingredients_list"))).rlike(".*(lettuce|tomato|cucumber|onion).*") &
            ~lower(concat_ws(" ", col("ingredients_list"))).rlike(".*(chicken|beef|pork|fish|pasta).*"),
            lit("starter")
        ).otherwise(lit("main_dish"))
    )
)

# Count recipes by category
category_counts = df_recipes_categorized.groupBy("category").agg(
    count("*").alias("recipe_count")
).orderBy(desc("recipe_count"))

print("\nRecipe distribution by category:")
category_counts.show(truncate=False)

# Separate recipes by category
df_starters = df_recipes_categorized.filter(col("category") == "starter")
df_main_dishes = df_recipes_categorized.filter(col("category") == "main_dish")
df_desserts = df_recipes_categorized.filter(col("category") == "dessert")

print(f"\nStarters: {df_starters.count():,}")
print(f"Main dishes: {df_main_dishes.count():,}")
print(f"Desserts: {df_desserts.count():,}")
# Out:
# ...
# CATEGORIZING RECIPES INTO STARTER, MAIN DISH, AND DESSERT
# ...
#
# Recipe distribution by category:
# +---------+------------+
# |category |recipe_count|
# +---------+------------+
# |dessert  |23855       |
# |main_dish|16195       |
# |starter  |9884        |
# +---------+------------+
#
#
# Starters: 9,884
# Main dishes: 16,195
# Desserts: 23,855

# %%
# Filter recipes by category for each dietary restriction
print("=" * 80)
print("FILTERING RECIPES BY CATEGORY AND DIETARY RESTRICTION")
print("=" * 80)

# Store filtered recipes by restriction and category
filtered_recipes_by_restriction = {}

for restriction_name, restriction_details in DIETARY_RESTRICTIONS.items():
    forbidden = restriction_details["forbidden"]
    
    # Create filter condition
    filter_condition = lit(True)
    for keyword in forbidden:
        filter_condition = filter_condition & (
            ~lower(concat_ws(" ", col("ingredients_list"))).contains(keyword.lower()) &
            ~lower(concat_ws(" ", col("ner_list"))).contains(keyword.lower())
        )
    
    # Filter each category
    starters_filtered = df_starters.filter(filter_condition)
    mains_filtered = df_main_dishes.filter(filter_condition)
    desserts_filtered = df_desserts.filter(filter_condition)
    
    filtered_recipes_by_restriction[restriction_name] = {
        "starter": starters_filtered,
        "main_dish": mains_filtered,
        "dessert": desserts_filtered
    }
    
    print(f"\n{restriction_name.upper()}:")
    print(f"  Starters: {starters_filtered.count():,}")
    print(f"  Main dishes: {mains_filtered.count():,}")
    print(f"  Desserts: {desserts_filtered.count():,}")

# Only process restrictions that have real user data
restrictions_to_process = [r for r in meal_distribution.keys() if r in filtered_recipes_by_restriction]
print(f"\nRestrictions with user data: {restrictions_to_process}")
# Out:
# ...
# FILTERING RECIPES BY CATEGORY AND DIETARY RESTRICTION
# ...
#
# VEGAN:
#   Starters: 2,977
#   Main dishes: 2,690
#   Desserts: 3,634
#
# VEGETARIAN:
#   Starters: 7,380
#   Main dishes: 6,347
#   Desserts: 22,616
#
# KOSHER:
#   Starters: 8,030
#   Main dishes: 12,854
#   Desserts: 21,846
#
# HALAL:
#   Starters: 7,753
#   Main dishes: 12,015
#   Desserts: 21,478
#
# GLUTEN_FREE:
#   Starters: 8,276
#   Main dishes: 12,119
#   Desserts: 12,079
#
# LACTOSE_INTOLERANT:
#   Starters: 4,658
#   Main dishes: 7,433
#   Desserts: 6,388
#
# NUT_ALLERGY:
#   Starters: 8,283
#   Main dishes: 14,182
#   Desserts: 15,426
#
# SHELLFISH_ALLERGY:
#   Starters: 9,237
#   Main dishes: 15,399
#   Desserts: 23,311
#
# EGG_ALLERGY:
#   Starters: 7,388
#   Main dishes: 12,992
#   Desserts: 12,434
#
# Restrictions with user data: ['nut_allergy', 'gluten_free', 'egg_allergy', 'shellfish_allergy', 'lactose_intolerant']

# %%
# Generate nutritious 3-course meals for each dietary restriction
# Each meal consists of: starter + main_dish + dessert
# Meals are selected to be nutritious and balanced

from pyspark.sql.functions import rand, monotonically_increasing_id, col, lit

print("=" * 80)
print("GENERATING NUTRITIOUS 3-COURSE MEALS")
print("=" * 80)

# Define the 5 allergic categories we need to process
ALLERGIC_CATEGORIES = [
    "gluten_free",
    "egg_allergy",
    "nut_allergy",
    "shellfish_allergy",
    "lactose_intolerant"
]

# Ensure restrictions_to_process is defined
if 'restrictions_to_process' not in globals():
    # Try to define it from available variables
    if 'meal_distribution' in globals() and 'filtered_recipes_by_restriction' in globals():
        restrictions_to_process = [r for r in meal_distribution.keys() if r in filtered_recipes_by_restriction]
    elif 'filtered_recipes_by_restriction' in globals():
        restrictions_to_process = [r for r in ALLERGIC_CATEGORIES if r in filtered_recipes_by_restriction]
    elif 'DIETARY_RESTRICTIONS' in globals():
        restrictions_to_process = [r for r in ALLERGIC_CATEGORIES if r in DIETARY_RESTRICTIONS]
    else:
        # Fallback: use the five allergic categories
        restrictions_to_process = ALLERGIC_CATEGORIES
    print(f"[INFO] Defined restrictions_to_process: {restrictions_to_process}")

# Check if menus are already saved - if so, load them instead of regenerating
import os
saved_menus_dir = "output/restaurant_menus"
if os.path.exists(saved_menus_dir) and len(restrictions_to_process) > 0:
    print(f"[INFO]  Checking for saved menus in {saved_menus_dir}...")
    loaded_count = 0
    for restriction in restrictions_to_process:
        menu_path = f"{saved_menus_dir}/{restriction}_restaurant_menu.parquet"
        if os.path.exists(menu_path):
            try:
                if 'restaurant_menus' not in globals():
                    restaurant_menus = {}
                restaurant_menus[restriction] = spark.read.parquet(menu_path)
                loaded_count += 1
                print(f"  [OK] Loaded saved menu: {restriction}")
            except Exception as e:
                print(f"  [WARN]  Could not load {restriction}: {e}")
    
    if loaded_count == len(restrictions_to_process):
        print(f"\n[OK] All {loaded_count} menus loaded from saved files. Skipping generation.")
        print(f"[INFO]  Menus are ready for SparkML recommendations.")
    elif loaded_count > 0:
        print(f"\n[INFO]  Loaded {loaded_count} menus. Will generate remaining menus.")
        # Update restrictions_to_process to only generate missing ones
        restrictions_to_process = [r for r in restrictions_to_process if r not in restaurant_menus]
    else:
        print("[INFO]  No saved menus found. Will generate new menus.")

# Ensure filtered_recipes_by_restriction is defined (needed if generating new menus)
if 'filtered_recipes_by_restriction' not in globals() and len(restrictions_to_process) > 0:
    print("[WARN]  filtered_recipes_by_restriction not found.")
    print("[INFO]  Cannot generate new menus without filtered recipes.")
    print("[INFO]  Please run previous cells to filter recipes, or ensure menus are saved.")
    filtered_recipes_by_restriction = {}

# Ensure meal_distribution is defined - use 20 meals per category for the 5 allergic categories
if 'meal_distribution' not in globals():
    print("[INFO]  meal_distribution not found. Using 20 meals per category for the 5 allergic categories.")
    meal_distribution = {r: 20 for r in ALLERGIC_CATEGORIES}

# Ensure DIETARY_RESTRICTIONS is defined (needed for description)
if 'DIETARY_RESTRICTIONS' not in globals():
    print("[INFO]  DIETARY_RESTRICTIONS not found. Using fallback descriptions.")
    DIETARY_RESTRICTIONS = {
        "gluten_free": {"description": "Gluten-free dietary restriction"},
        "egg_allergy": {"description": "Egg allergy dietary restriction"},
        "nut_allergy": {"description": "Nut allergy dietary restriction"},
        "shellfish_allergy": {"description": "Shellfish allergy dietary restriction"},
        "lactose_intolerant": {"description": "Lactose intolerant dietary restriction"}
    }

# Initialize restaurant_menus if not already loaded
if 'restaurant_menus' not in globals():
    restaurant_menus = {}

# Only generate menus if we have restrictions to process and filtered recipes
if len(restrictions_to_process) > 0 and len(filtered_recipes_by_restriction) > 0:
    print(f"\n[INFO]  Generating menus for {len(restrictions_to_process)} restrictions...")
    
    for restriction in restrictions_to_process:
        if restriction not in filtered_recipes_by_restriction:
            continue
        
        meals_needed = meal_distribution.get(restriction, 0)
        if meals_needed == 0:
            continue
        
        starters_df = filtered_recipes_by_restriction[restriction]["starter"]
        mains_df = filtered_recipes_by_restriction[restriction]["main_dish"]
        desserts_df = filtered_recipes_by_restriction[restriction]["dessert"]
        
        starter_count = starters_df.count()
        main_count = mains_df.count()
        dessert_count = desserts_df.count()
        
        if starter_count == 0 or main_count == 0 or dessert_count == 0:
            print(f"\n[WARN]  {restriction}: Insufficient recipes in all categories")
            continue
        
        print(f"\n{restriction.upper()}: Generating {meals_needed} meals")
        print(f"  Available: {starter_count} starters, {main_count} mains, {dessert_count} desserts")
        
        # Sample recipes randomly (with seed for reproducibility)
        # Ensure we have enough recipes
        max_meals = min(starter_count, main_count, dessert_count)
        actual_meals = min(meals_needed, max_meals)
        
        # Get random samples
        starters_sample = starters_df.orderBy(rand(seed=42)).limit(actual_meals)
        mains_sample = mains_df.orderBy(rand(seed=42)).limit(actual_meals)
        desserts_sample = desserts_df.orderBy(rand(seed=42)).limit(actual_meals)
        
        # Add row numbers to combine
        starters_with_id = starters_sample.withColumn("meal_id", monotonically_increasing_id())
        mains_with_id = mains_sample.withColumn("meal_id", monotonically_increasing_id())
        desserts_with_id = desserts_sample.withColumn("meal_id", monotonically_increasing_id())
        
        # Combine into meals
        meals_combined = starters_with_id.select(
            col("meal_id"),
            col("title").alias("starter_title"),
            col("ingredients_list").alias("starter_ingredients"),
            col("directions").alias("starter_directions"),
            col("link").alias("starter_link")
        ).join(
            mains_with_id.select(
                col("meal_id"),
                col("title").alias("main_title"),
                col("ingredients_list").alias("main_ingredients"),
                col("directions").alias("main_directions"),
                col("link").alias("main_link")
            ),
            on="meal_id",
            how="inner"
        ).join(
            desserts_with_id.select(
                col("meal_id"),
                col("title").alias("dessert_title"),
                col("ingredients_list").alias("dessert_ingredients"),
                col("directions").alias("dessert_directions"),
                col("link").alias("dessert_link")
            ),
            on="meal_id",
            how="inner"
        ).withColumn(
            "dietary_restriction",
            lit(restriction)
        ).withColumn(
            "restriction_description",
            lit(DIETARY_RESTRICTIONS[restriction]["description"])
        )
        
        restaurant_menus[restriction] = meals_combined
        
        print(f"  [OK] Generated {meals_combined.count()} meals")
    
    print(f"\n[OK] Total restrictions processed: {len(restaurant_menus)}")
else:
    if len(restrictions_to_process) == 0:
        print("\n[INFO]  No restrictions to process.")
    elif len(filtered_recipes_by_restriction) == 0:
        print("\n[INFO]  No filtered recipes available. Menus may have been loaded from saved files.")
    
    if len(restaurant_menus) > 0:
        print(f"[OK] Total menus available: {len(restaurant_menus)}")

# Save menus to output folder
if len(restaurant_menus) > 0:
    import os
    output_dir = "output/restaurant_menus"
    os.makedirs(output_dir, exist_ok=True)
    
    print(f"\n{'='*80}")
    print("SAVING RESTAURANT MENUS TO OUTPUT FOLDER")
    print(f"{'='*80}")
    
    for restriction, meals_df in restaurant_menus.items():
        output_path = f"{output_dir}/{restriction}_restaurant_menu.parquet"
        try:
            meals_df.repartition(1).write.mode("overwrite").parquet(output_path)
            meal_count = meals_df.count()
            print(f"[OK] Saved {restriction}: {meal_count} meals to {output_path}")
        except Exception as e:
            print(f"[WARN]  Could not save {restriction}: {e}")
    
    print(f"\n[OK] All menus saved to: {output_dir}")
else:
    print("\n[WARN]  No menus to save. Please check if filtered_recipes_by_restriction is populated.")
# Out:
# ...
# GENERATING NUTRITIOUS 3-COURSE MEALS
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11 # Store generated meals
#      12 restaurant_menus = {}
# ---> 14 for restriction in restrictions_to_process:
#      15     if restriction not in filtered_recipes_by_restriction:
#      16         continue
#
# NameError: name 'restrictions_to_process' is not defined

# %%
# Display sample meals for each restriction
print("=" * 80)
print("SAMPLE RESTAURANT MENUS BY DIETARY RESTRICTION")
print("=" * 80)

for restriction, meals_df in restaurant_menus.items():
    meal_count = meals_df.count()
    user_count = allergy_distribution[restriction]["user_count"]
    percentage = allergy_distribution[restriction]["percentage"]

    print(f"\n{'='*80}")
    print(f"RESTRICTION: {restriction.upper()}")
    print(f"Description: {DIETARY_RESTRICTIONS[restriction]['description']}")
    print(f"User representation: {user_count:,} users ({percentage}% of allergic users)")
    print(f"Meals generated: {meal_count}")
    print(f"{'='*80}")

    # Show first 3 meals
    sample_meals = meals_df.limit(3).collect()

    for idx, meal in enumerate(sample_meals, 1):
        print(f"\n--- MEAL {idx} ---")
        print(f"\nSTARTER:")
        print(f"  {meal['starter_title']}")
        print(f"  Ingredients: {', '.join(meal['starter_ingredients'][:3])}...")

        print(f"\nMAIN DISH:")
        print(f"  {meal['main_title']}")
        print(f"  Ingredients: {', '.join(meal['main_ingredients'][:3])}...")

        print(f"\nDESSERT:")
        print(f"  {meal['dessert_title']}")
        print(f"  Ingredients: {', '.join(meal['dessert_ingredients'][:3])}...")

        if idx < len(sample_meals):
            print(f"\n{'-'*80}")

# %%
# Save restaurant menus to parquet files
output_dir = "D:/1-master/2024-2026/1-ISST/BigDataAnalitics/1-labs/fii-bda/FII-BDA/output/restaurant_menus"
os.makedirs(output_dir, exist_ok=True)

print("=" * 80)
print("SAVING RESTAURANT MENUS TO PARQUET FILES")
print("=" * 80)

for restriction, meals_df in restaurant_menus.items():
    meal_count = meals_df.count()

    if meal_count == 0:
        print(f"\n[WARN]  {restriction}: No meals to save")
        continue

    output_path = f"{output_dir}/{restriction}_restaurant_menu.parquet"

    try:
        meals_df.repartition(1).write.mode("overwrite").parquet(output_path)
        print(f"[OK] {restriction}: Saved {meal_count} meals to {output_path}")
    except Exception as e:
        print(f"[WARN]  {restriction}: Spark write failed, trying pandas fallback...")
        try:
            import pandas as pd
            from pathlib import Path

            Path(output_path).mkdir(parents=True, exist_ok=True)
            pdf = meals_df.toPandas()
            output_file = f"{output_path}/{restriction}_restaurant_menu.parquet"
            pdf.to_parquet(output_file, engine="pyarrow", index=False)
            print(f"[OK] {restriction}: Saved {len(pdf)} meals using pandas")
        except Exception as e2:
            print(f"❌ {restriction}: Failed to save - {str(e2)[:100]}")

# Create combined restaurant menu
print("\n" + "=" * 80)
print("CREATING COMBINED RESTAURANT MENU")
print("=" * 80)

from functools import reduce

menu_dfs = []
for restriction, meals_df in restaurant_menus.items():
    if meals_df.count() > 0:
        menu_dfs.append(meals_df)

if menu_dfs:
    df_all_restaurant_menus = reduce(lambda df1, df2: df1.union(df2), menu_dfs)

    combined_output = f"{output_dir}/all_restaurant_menus.parquet"

    try:
        df_all_restaurant_menus.repartition(1).write.mode("overwrite").parquet(combined_output)
        print(f"[OK] Combined menu saved: {df_all_restaurant_menus.count():,} total meals")
    except Exception as e:
        print(f"[WARN]  Spark write failed, trying pandas fallback...")
        try:
            import pandas as pd
            from pathlib import Path

            Path(combined_output).mkdir(parents=True, exist_ok=True)
            pdf = df_all_restaurant_menus.toPandas()
            output_file = f"{combined_output}/all_restaurant_menus.parquet"
            pdf.to_parquet(output_file, engine="pyarrow", index=False)
            print(f"[OK] Combined menu saved using pandas: {len(pdf):,} meals")
        except Exception as e2:
            print(f"❌ Failed to save combined menu: {str(e2)[:100]}")

    # Show summary
    print("\n" + "=" * 80)
    print("RESTAURANT MENU SUMMARY")
    print("=" * 80)

    summary_df = df_all_restaurant_menus.groupBy("dietary_restriction").agg(
        count("*").alias("meal_count")
    ).orderBy(desc("meal_count"))

    print("\nMeals by dietary restriction:")
    summary_df.show(truncate=False)

    total_meals = df_all_restaurant_menus.count()
    print(f"\nTotal meals generated: {total_meals}")
    print(f"Meals saved to: {output_dir}")
else:
    print("[WARN]  No menus to combine")

# %%
# Identify recipes that violate specific restrictions (for analysis)
print("=" * 80)
print("ANALYZING RECIPE VIOLATIONS")
print("=" * 80)

# For each restriction, identify which recipes violate it and why
violation_analysis = {}

for restriction_name, restriction_details in DIETARY_RESTRICTIONS.items():
    forbidden = restriction_details["forbidden"]
    
    # Get non-compliant recipes
    filter_condition = lit(False)
    for keyword in forbidden:
        filter_condition = filter_condition | (
            lower(concat_ws(" ", col("ingredients_list"))).contains(keyword.lower()) |
            lower(concat_ws(" ", col("ner_list"))).contains(keyword.lower())
        )
    
    df_violations = df_recipes_parsed.filter(filter_condition)
    violation_count = df_violations.count()
    
    # Identify which forbidden ingredients appear most frequently
    violation_keywords = {}
    for keyword in forbidden:
        keyword_count = df_violations.filter(
            lower(concat_ws(" ", col("ingredients_list"))).contains(keyword.lower()) |
            lower(concat_ws(" ", col("ner_list"))).contains(keyword.lower())
        ).count()
        if keyword_count > 0:
            violation_keywords[keyword] = keyword_count
    
    violation_analysis[restriction_name] = {
        "total_violations": violation_count,
        "top_violations": dict(sorted(violation_keywords.items(), key=lambda x: x[1], reverse=True)[:5])
    }
    
    print(f"\n{restriction_name.upper()}:")
    print(f"  Total violations: {violation_count:,}")
    print(f"  Top forbidden ingredients found:")
    for ingredient, count in violation_analysis[restriction_name]["top_violations"].items():
        print(f"    - {ingredient}: {count:,} recipes")

print("\n" + "=" * 80)
print("SUMMARY")
print("=" * 80)
print(f"Total recipes analyzed: {df_recipes_parsed.count():,}")
print(f"Dietary restrictions analyzed: {len(DIETARY_RESTRICTIONS)}")
print(f"\n[OK] Menu generation and analysis complete!")
# Out:
# ...
# ANALYZING RECIPE VIOLATIONS
# ...
#
# VEGAN:
#   Total violations: 40,633
#   Top forbidden ingredients found:
#     - egg: 15,384 recipes
#     - butter: 15,329 recipes
#     - cheese: 12,319 recipes
#     - milk: 11,174 recipes
#     - cream: 11,153 recipes
#
# VEGETARIAN:
#   Total violations: 13,591
#   Top forbidden ingredients found:
#     - chicken: 6,524 recipes
#     - beef: 3,749 recipes
#     - pork: 1,759 recipes
#     - meat: 1,267 recipes
#     - turkey: 856 recipes
#
# KOSHER:
#   Total violations: 7,204
#   Top forbidden ingredients found:
#     - ham: 2,570 recipes
#     - bacon: 1,938 recipes
#     - pork: 1,759 recipes
#     - shrimp: 1,011 recipes
#     - crab: 483 recipes
#
# HALAL:
#   Total violations: 8,688
#   Top forbidden ingredients found:
#     - wine: 2,890 recipes
#     - ham: 2,570 recipes
#     - bacon: 1,938 recipes
#     - pork: 1,759 recipes
#     - beer: 274 recipes
#
# GLUTEN_FREE:
#   Total violations: 17,460
#   Top forbidden ingredients found:
# ...
